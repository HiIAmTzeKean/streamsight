# %% [markdown]
# # Demo of streamsight Pipeline
#
# - Dataset: MovieLens
# - Algorithm: ItemKNN Incremental

# %%
874724710 + 60 * 60 * 24 * 5
# Out:
# 875156710

# %%
from streamsight.datasets import MovieLens100K
from streamsight.settings import SlidingWindowSetting


k = 100
dataset = MovieLens100K()
data = dataset.load()

setting_window = SlidingWindowSetting(
    background_t=874724710 + 60 * 60 * 24 * 5,
    window_size=60 * 60 * 24 * 30,  # day times N
    top_K=k
)

setting_window.split(data)
# Out:
# INFO - streamsight package loaded.
# DEBUG - MovieLens100K being initialized with '/Users/ngtzekean/personal/streamsight/data/movielens' as the base path.
# DEBUG - MovieLens100K is initialized.
# INFO - MovieLens100K is loading dataset...
# INFO - Loading from cache: /Users/ngtzekean/personal/streamsight/data/movielens/ml-100k_u.data.processed.parquet
# DEBUG - MovieLens100K applying filters set.
# DEBUG - 	interactions before preprocess: 100000
# DEBUG - 	items before preprocess: 1682
# DEBUG - 	users before preprocess: 943
# DEBUG - 	interactions after preprocess: 100000
# DEBUG - 	items after preprocess: 1682
# DEBUG - 	users after preprocess: 943
# INFO - MovieLens100K dataset loaded - Took 0.0447s
# DEBUG - Splitting data...
# DEBUG - Performing lt(t, 2147483647)
# DEBUG - Performing lt(t, 875156710)
# DEBUG - Performing ge(t, 875156710)
# DEBUG - TimestampSplitter(t=875156710,t_lower=None,t_upper=None) has complete split
#   0%|          | 0/6 [00:00<?, ?it/s]
# DEBUG - NLastInteractionTimestampSplitter(t=875156710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=875156710
# DEBUG - Performing lt(t, 877748710)
# DEBUG - Performing ge(t, 875156710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=875156710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 875156710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=875156710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=877748710
# DEBUG - Performing lt(t, 880340710)
# DEBUG - Performing ge(t, 877748710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=877748710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 877748710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=877748710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=880340710
# DEBUG - Performing lt(t, 882932710)
# DEBUG - Performing ge(t, 880340710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=880340710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 880340710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=880340710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=882932710
# DEBUG - Performing lt(t, 885524710)
# DEBUG - Performing ge(t, 882932710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=882932710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 882932710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=882932710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=885524710
# DEBUG - Performing lt(t, 888116710)
# DEBUG - Performing ge(t, 885524710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=885524710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 885524710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=885524710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=888116710
# DEBUG - Performing lt(t, 890708710)
# DEBUG - Performing ge(t, 888116710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=888116710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 888116710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=888116710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=890708710
# DEBUG - Performing lt(t, 893300710)
# DEBUG - Performing ge(t, 890708710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=890708710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 890708710 resulted in empty unlabelled testing samples.
# 7it [00:00, 188.98it/s]
# INFO - Finished split with window size 2592000 seconds. Number of splits: 7 in total.
# INFO - SlidingWindowSetting data split - Took 0.0504s
# DEBUG - Checking split attribute and sizes.
# DEBUG - Checking split attributes.
# DEBUG - Split attributes are set.
# DEBUG - Checking size of split sets.
# WARNING - /Users/ngtzekean/personal/streamsight/src/streamsight/settings/base.py:274: UserWarning: Background data resulting from SlidingWindowSetting is unusually small.
#   warn(UserWarning(f"{name} resulting from {self.name} is unusually small."))
#
# DEBUG - Size of split sets are checked.
# INFO - SlidingWindowSetting data split complete.

# %%
from streamsight.algorithms import ItemKNNIncremental, MostPopular, RecentPopularity
from streamsight.evaluators import EvaluatorPipelineBuilder


builder = EvaluatorPipelineBuilder()
builder.add_setting(setting_window)
builder.set_metric_K(k)
builder.add_metric("PrecisionK")
builder.add_metric("RecallK")
builder.add_algorithm(ItemKNNIncremental, params={"K": k})
builder.add_algorithm(MostPopular, params={"K": k})
builder.add_algorithm(RecentPopularity, params={"K": k})
evaluator = builder.build()
# Out:
# INFO - Registered algorithm 'ItemKNNIncremental(K=100,pad_with_popularity=False)' with ID b82ad9b0-f27f-5ba9-954d-9324325a70d0
# INFO - Registered algorithm 'MostPopular(K=100)' with ID aa5654e1-ae99-5359-a24b-743deef3f554
# INFO - Registered algorithm 'RecentPopularity(K=100)' with ID 6472b555-35ba-5b5a-beb6-5161507aba5f

# %%
evaluator.run()
# Out:
# INFO - Phase 1: Preparing the evaluator...
# DEBUG - (user x item) shape defined is (41, 872). Shape of dataframe stored in matrix was (3446, 5) before masking
# DEBUG - Shape of dataframe stored in matrix is now (3446, 5) after masking
# DEBUG - Final (user x item) shape defined is (41, 872)
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.0394s
# DEBUG - Fitting MostPopular complete - Took 0.0011s
# DEBUG - Fitting RecentPopularity complete - Took 0.000832s
# DEBUG - Algorithms trained with background data...
# DEBUG - Metric accumulator instantiated...
# DEBUG - Restoring setting to iteration 0
# DEBUG - Setting data generators ready...
# Evaluating steps:   0%|          | 0/7 [00:00<?, ?it/s]
# INFO - Running step 0
# INFO - Phase 2: Evaluating the algorithms...
# DEBUG - (user x item) shape defined is (174, 872). Shape of dataframe stored in matrix was (8818, 5) before masking
# DEBUG - Shape of dataframe stored in matrix is now (8818, 5) after masking
# DEBUG - Final (user x item) shape defined is (174, 872)
# DEBUG - (user x item) shape defined is (174, 872). Shape of dataframe stored in matrix was (8818, 5) before masking
# DEBUG - Shape of dataframe stored in matrix is now (8818, 5) after masking
# DEBUG - Final (user x item) shape defined is (174, 1189)
# DEBUG - Performing items_in comparison
# DEBUG - Padding user ID in range(41, 174) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Shape of prediction matrix: (8818, 872)
# DEBUG - Shape of ground truth matrix: (8818, 1189)
# WARNING - Prediction matrix shape (8818, 872) is different from ground truth matrix shape (8818, 1189).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (8818, 1189)
# DEBUG - Number of ground truth interactions: 8818
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=875156710) created for algorithm ItemKNNIncremental(K=100,pad_with_popularity=False)_b82ad9b0-f27f-5ba9-954d-9324325a70d0
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (8818, 1189)
# DEBUG - Number of ground truth interactions: 8818
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=875156710) created for algorithm ItemKNNIncremental(K=100,pad_with_popularity=False)_b82ad9b0-f27f-5ba9-954d-9324325a70d0
# DEBUG - Performing items_in comparison
# DEBUG - Shape of prediction matrix: (8818, 872)
# DEBUG - Shape of ground truth matrix: (8818, 1189)
# WARNING - Prediction matrix shape (8818, 872) is different from ground truth matrix shape (8818, 1189).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (8818, 1189)
# DEBUG - Number of ground truth interactions: 8818
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=875156710) created for algorithm MostPopular(K=100)_aa5654e1-ae99-5359-a24b-743deef3f554
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (8818, 1189)
# DEBUG - Number of ground truth interactions: 8818
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=875156710) created for algorithm MostPopular(K=100)_aa5654e1-ae99-5359-a24b-743deef3f554
# DEBUG - Performing items_in comparison
# DEBUG - Shape of prediction matrix: (8818, 872)
# DEBUG - Shape of ground truth matrix: (8818, 1189)
# WARNING - Prediction matrix shape (8818, 872) is different from ground truth matrix shape (8818, 1189).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (8818, 1189)
# DEBUG - Number of ground truth interactions: 8818
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=875156710) created for algorithm RecentPopularity(K=100)_6472b555-35ba-5b5a-beb6-5161507aba5f
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (8818, 1189)
# DEBUG - Number of ground truth interactions: 8818
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=875156710) created for algorithm RecentPopularity(K=100)_6472b555-35ba-5b5a-beb6-5161507aba5f
# Evaluating steps:  14%|█▍        | 1/7 [00:00<00:00,  7.06it/s]
# INFO - Phase 3: Releasing the data...
# DEBUG - (user x item) shape defined is (174, 1192). Shape of dataframe stored in matrix was (11661, 5) before masking
# DEBUG - Shape of dataframe stored in matrix is now (11661, 5) after masking
# DEBUG - Final (user x item) shape defined is (174, 1192)
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.0541s
# DEBUG - Fitting MostPopular complete - Took 0.00125s
# DEBUG - Fitting RecentPopularity complete - Took 0.000957s
# INFO - Running step 1
# INFO - Phase 2: Evaluating the algorithms...
# DEBUG - (user x item) shape defined is (391, 1192). Shape of dataframe stored in matrix was (15037, 5) before masking
# DEBUG - Shape of dataframe stored in matrix is now (15037, 5) after masking
# DEBUG - Final (user x item) shape defined is (391, 1192)
# DEBUG - (user x item) shape defined is (391, 1192). Shape of dataframe stored in matrix was (15037, 5) before masking
# DEBUG - Shape of dataframe stored in matrix is now (15037, 5) after masking
# DEBUG - Final (user x item) shape defined is (391, 1404)
# DEBUG - Performing items_in comparison
# DEBUG - Padding user ID in range(174, 391) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Shape of prediction matrix: (15037, 1192)
# DEBUG - Shape of ground truth matrix: (15037, 1404)
# WARNING - Prediction matrix shape (15037, 1192) is different from ground truth matrix shape (15037, 1404).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (15037, 1404)
# DEBUG - Number of ground truth interactions: 15037
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=877748710) created for algorithm ItemKNNIncremental(K=100,pad_with_popularity=False)_b82ad9b0-f27f-5ba9-954d-9324325a70d0
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (15037, 1404)
# DEBUG - Number of ground truth interactions: 15037
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=877748710) created for algorithm ItemKNNIncremental(K=100,pad_with_popularity=False)_b82ad9b0-f27f-5ba9-954d-9324325a70d0
# DEBUG - Performing items_in comparison
# DEBUG - Shape of prediction matrix: (15037, 1192)
# DEBUG - Shape of ground truth matrix: (15037, 1404)
# WARNING - Prediction matrix shape (15037, 1192) is different from ground truth matrix shape (15037, 1404).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (15037, 1404)
# DEBUG - Number of ground truth interactions: 15037
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=877748710) created for algorithm MostPopular(K=100)_aa5654e1-ae99-5359-a24b-743deef3f554
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (15037, 1404)
# DEBUG - Number of ground truth interactions: 15037
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=877748710) created for algorithm MostPopular(K=100)_aa5654e1-ae99-5359-a24b-743deef3f554
# DEBUG - Performing items_in comparison
# DEBUG - Shape of prediction matrix: (15037, 1192)
# DEBUG - Shape of ground truth matrix: (15037, 1404)
# WARNING - Prediction matrix shape (15037, 1192) is different from ground truth matrix shape (15037, 1404).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (15037, 1404)
# DEBUG - Number of ground truth interactions: 15037
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=877748710) created for algorithm RecentPopularity(K=100)_6472b555-35ba-5b5a-beb6-5161507aba5f
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (15037, 1404)
# DEBUG - Number of ground truth interactions: 15037
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=877748710) created for algorithm RecentPopularity(K=100)_6472b555-35ba-5b5a-beb6-5161507aba5f
# Evaluating steps:  29%|██▊       | 2/7 [00:00<00:01,  4.48it/s]
# INFO - Phase 3: Releasing the data...
# DEBUG - (user x item) shape defined is (391, 1411). Shape of dataframe stored in matrix was (21810, 5) before masking
# DEBUG - Shape of dataframe stored in matrix is now (21810, 5) after masking
# DEBUG - Final (user x item) shape defined is (391, 1411)
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.0703s
# DEBUG - Fitting MostPopular complete - Took 0.00141s
# DEBUG - Fitting RecentPopularity complete - Took 0.00108s
# INFO - Running step 2
# INFO - Phase 2: Evaluating the algorithms...
# DEBUG - (user x item) shape defined is (497, 1411). Shape of dataframe stored in matrix was (8932, 5) before masking
# DEBUG - Shape of dataframe stored in matrix is now (8932, 5) after masking
# DEBUG - Final (user x item) shape defined is (497, 1411)
# DEBUG - (user x item) shape defined is (497, 1411). Shape of dataframe stored in matrix was (8932, 5) before masking
# DEBUG - Shape of dataframe stored in matrix is now (8932, 5) after masking
# DEBUG - Final (user x item) shape defined is (497, 1467)
# DEBUG - Performing items_in comparison
# DEBUG - Padding user ID in range(391, 497) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Shape of prediction matrix: (8932, 1411)
# DEBUG - Shape of ground truth matrix: (8932, 1467)
# WARNING - Prediction matrix shape (8932, 1411) is different from ground truth matrix shape (8932, 1467).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (8932, 1467)
# DEBUG - Number of ground truth interactions: 8932
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=880340710) created for algorithm ItemKNNIncremental(K=100,pad_with_popularity=False)_b82ad9b0-f27f-5ba9-954d-9324325a70d0
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (8932, 1467)
# DEBUG - Number of ground truth interactions: 8932
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=880340710) created for algorithm ItemKNNIncremental(K=100,pad_with_popularity=False)_b82ad9b0-f27f-5ba9-954d-9324325a70d0
# DEBUG - Performing items_in comparison
# DEBUG - Shape of prediction matrix: (8932, 1411)
# DEBUG - Shape of ground truth matrix: (8932, 1467)
# WARNING - Prediction matrix shape (8932, 1411) is different from ground truth matrix shape (8932, 1467).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (8932, 1467)
# DEBUG - Number of ground truth interactions: 8932
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=880340710) created for algorithm MostPopular(K=100)_aa5654e1-ae99-5359-a24b-743deef3f554
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (8932, 1467)
# DEBUG - Number of ground truth interactions: 8932
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=880340710) created for algorithm MostPopular(K=100)_aa5654e1-ae99-5359-a24b-743deef3f554
# DEBUG - Performing items_in comparison
# DEBUG - Shape of prediction matrix: (8932, 1411)
# DEBUG - Shape of ground truth matrix: (8932, 1467)
# WARNING - Prediction matrix shape (8932, 1411) is different from ground truth matrix shape (8932, 1467).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (8932, 1467)
# DEBUG - Number of ground truth interactions: 8932
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=880340710) created for algorithm RecentPopularity(K=100)_6472b555-35ba-5b5a-beb6-5161507aba5f
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (8932, 1467)
# DEBUG - Number of ground truth interactions: 8932
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=880340710) created for algorithm RecentPopularity(K=100)_6472b555-35ba-5b5a-beb6-5161507aba5f
# Evaluating steps:  43%|████▎     | 3/7 [00:00<00:00,  4.25it/s]
# INFO - Phase 3: Releasing the data...
# DEBUG - (user x item) shape defined is (497, 1467). Shape of dataframe stored in matrix was (13649, 5) before masking
# DEBUG - Shape of dataframe stored in matrix is now (13649, 5) after masking
# DEBUG - Final (user x item) shape defined is (497, 1467)
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.0763s
# DEBUG - Fitting MostPopular complete - Took 0.00124s
# DEBUG - Fitting RecentPopularity complete - Took 0.000815s
# INFO - Running step 3
# INFO - Phase 2: Evaluating the algorithms...
# DEBUG - (user x item) shape defined is (618, 1467). Shape of dataframe stored in matrix was (8574, 5) before masking
# DEBUG - Shape of dataframe stored in matrix is now (8574, 5) after masking
# DEBUG - Final (user x item) shape defined is (618, 1467)
# DEBUG - (user x item) shape defined is (618, 1467). Shape of dataframe stored in matrix was (8574, 5) before masking
# DEBUG - Shape of dataframe stored in matrix is now (8574, 5) after masking
# DEBUG - Final (user x item) shape defined is (618, 1515)
# DEBUG - Performing items_in comparison
# DEBUG - Padding user ID in range(497, 618) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Shape of prediction matrix: (8574, 1467)
# DEBUG - Shape of ground truth matrix: (8574, 1515)
# WARNING - Prediction matrix shape (8574, 1467) is different from ground truth matrix shape (8574, 1515).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (8574, 1515)
# DEBUG - Number of ground truth interactions: 8574
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=882932710) created for algorithm ItemKNNIncremental(K=100,pad_with_popularity=False)_b82ad9b0-f27f-5ba9-954d-9324325a70d0
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (8574, 1515)
# DEBUG - Number of ground truth interactions: 8574
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=882932710) created for algorithm ItemKNNIncremental(K=100,pad_with_popularity=False)_b82ad9b0-f27f-5ba9-954d-9324325a70d0
# DEBUG - Performing items_in comparison
# DEBUG - Shape of prediction matrix: (8574, 1467)
# DEBUG - Shape of ground truth matrix: (8574, 1515)
# WARNING - Prediction matrix shape (8574, 1467) is different from ground truth matrix shape (8574, 1515).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (8574, 1515)
# DEBUG - Number of ground truth interactions: 8574
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=882932710) created for algorithm MostPopular(K=100)_aa5654e1-ae99-5359-a24b-743deef3f554
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (8574, 1515)
# DEBUG - Number of ground truth interactions: 8574
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=882932710) created for algorithm MostPopular(K=100)_aa5654e1-ae99-5359-a24b-743deef3f554
# DEBUG - Performing items_in comparison
# DEBUG - Shape of prediction matrix: (8574, 1467)
# DEBUG - Shape of ground truth matrix: (8574, 1515)
# WARNING - Prediction matrix shape (8574, 1467) is different from ground truth matrix shape (8574, 1515).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (8574, 1515)
# DEBUG - Number of ground truth interactions: 8574
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=882932710) created for algorithm RecentPopularity(K=100)_6472b555-35ba-5b5a-beb6-5161507aba5f
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (8574, 1515)
# DEBUG - Number of ground truth interactions: 8574
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=882932710) created for algorithm RecentPopularity(K=100)_6472b555-35ba-5b5a-beb6-5161507aba5f
# Evaluating steps:  57%|█████▋    | 4/7 [00:00<00:00,  4.25it/s]
# INFO - Phase 3: Releasing the data...
# DEBUG - (user x item) shape defined is (618, 1515). Shape of dataframe stored in matrix was (12069, 5) before masking
# DEBUG - Shape of dataframe stored in matrix is now (12069, 5) after masking
# DEBUG - Final (user x item) shape defined is (618, 1515)
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.0813s
# DEBUG - Fitting MostPopular complete - Took 0.00119s
# DEBUG - Fitting RecentPopularity complete - Took 0.000767s
# INFO - Running step 4
# INFO - Phase 2: Evaluating the algorithms...
# DEBUG - (user x item) shape defined is (703, 1515). Shape of dataframe stored in matrix was (7041, 5) before masking
# DEBUG - Shape of dataframe stored in matrix is now (7041, 5) after masking
# DEBUG - Final (user x item) shape defined is (703, 1515)
# DEBUG - (user x item) shape defined is (703, 1515). Shape of dataframe stored in matrix was (7041, 5) before masking
# DEBUG - Shape of dataframe stored in matrix is now (7041, 5) after masking
# DEBUG - Final (user x item) shape defined is (703, 1594)
# DEBUG - Performing items_in comparison
# DEBUG - Padding user ID in range(618, 703) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Shape of prediction matrix: (7041, 1515)
# DEBUG - Shape of ground truth matrix: (7041, 1594)
# WARNING - Prediction matrix shape (7041, 1515) is different from ground truth matrix shape (7041, 1594).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (7041, 1594)
# DEBUG - Number of ground truth interactions: 7041
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=885524710) created for algorithm ItemKNNIncremental(K=100,pad_with_popularity=False)_b82ad9b0-f27f-5ba9-954d-9324325a70d0
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (7041, 1594)
# DEBUG - Number of ground truth interactions: 7041
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=885524710) created for algorithm ItemKNNIncremental(K=100,pad_with_popularity=False)_b82ad9b0-f27f-5ba9-954d-9324325a70d0
# DEBUG - Performing items_in comparison
# DEBUG - Shape of prediction matrix: (7041, 1515)
# DEBUG - Shape of ground truth matrix: (7041, 1594)
# WARNING - Prediction matrix shape (7041, 1515) is different from ground truth matrix shape (7041, 1594).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (7041, 1594)
# DEBUG - Number of ground truth interactions: 7041
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=885524710) created for algorithm MostPopular(K=100)_aa5654e1-ae99-5359-a24b-743deef3f554
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (7041, 1594)
# DEBUG - Number of ground truth interactions: 7041
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=885524710) created for algorithm MostPopular(K=100)_aa5654e1-ae99-5359-a24b-743deef3f554
# DEBUG - Performing items_in comparison
# DEBUG - Shape of prediction matrix: (7041, 1515)
# DEBUG - Shape of ground truth matrix: (7041, 1594)
# WARNING - Prediction matrix shape (7041, 1515) is different from ground truth matrix shape (7041, 1594).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (7041, 1594)
# DEBUG - Number of ground truth interactions: 7041
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=885524710) created for algorithm RecentPopularity(K=100)_6472b555-35ba-5b5a-beb6-5161507aba5f
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (7041, 1594)
# DEBUG - Number of ground truth interactions: 7041
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=885524710) created for algorithm RecentPopularity(K=100)_6472b555-35ba-5b5a-beb6-5161507aba5f
# Evaluating steps:  71%|███████▏  | 5/7 [00:01<00:00,  4.25it/s]
# INFO - Phase 3: Releasing the data...
# DEBUG - (user x item) shape defined is (703, 1594). Shape of dataframe stored in matrix was (11669, 5) before masking
# DEBUG - Shape of dataframe stored in matrix is now (11669, 5) after masking
# DEBUG - Final (user x item) shape defined is (703, 1594)
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.0919s
# DEBUG - Fitting MostPopular complete - Took 0.00117s
# DEBUG - Fitting RecentPopularity complete - Took 0.000854s
# INFO - Running step 5
# INFO - Phase 2: Evaluating the algorithms...
# DEBUG - (user x item) shape defined is (782, 1594). Shape of dataframe stored in matrix was (6441, 5) before masking
# DEBUG - Shape of dataframe stored in matrix is now (6441, 5) after masking
# DEBUG - Final (user x item) shape defined is (782, 1594)
# DEBUG - (user x item) shape defined is (782, 1594). Shape of dataframe stored in matrix was (6441, 5) before masking
# DEBUG - Shape of dataframe stored in matrix is now (6441, 5) after masking
# DEBUG - Final (user x item) shape defined is (782, 1626)
# DEBUG - Performing items_in comparison
# DEBUG - Padding user ID in range(703, 782) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Shape of prediction matrix: (6441, 1594)
# DEBUG - Shape of ground truth matrix: (6441, 1626)
# WARNING - Prediction matrix shape (6441, 1594) is different from ground truth matrix shape (6441, 1626).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (6441, 1626)
# DEBUG - Number of ground truth interactions: 6441
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=888116710) created for algorithm ItemKNNIncremental(K=100,pad_with_popularity=False)_b82ad9b0-f27f-5ba9-954d-9324325a70d0
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (6441, 1626)
# DEBUG - Number of ground truth interactions: 6441
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=888116710) created for algorithm ItemKNNIncremental(K=100,pad_with_popularity=False)_b82ad9b0-f27f-5ba9-954d-9324325a70d0
# DEBUG - Performing items_in comparison
# DEBUG - Shape of prediction matrix: (6441, 1594)
# DEBUG - Shape of ground truth matrix: (6441, 1626)
# WARNING - Prediction matrix shape (6441, 1594) is different from ground truth matrix shape (6441, 1626).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (6441, 1626)
# DEBUG - Number of ground truth interactions: 6441
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=888116710) created for algorithm MostPopular(K=100)_aa5654e1-ae99-5359-a24b-743deef3f554
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (6441, 1626)
# DEBUG - Number of ground truth interactions: 6441
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=888116710) created for algorithm MostPopular(K=100)_aa5654e1-ae99-5359-a24b-743deef3f554
# DEBUG - Performing items_in comparison
# DEBUG - Shape of prediction matrix: (6441, 1594)
# DEBUG - Shape of ground truth matrix: (6441, 1626)
# WARNING - Prediction matrix shape (6441, 1594) is different from ground truth matrix shape (6441, 1626).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (6441, 1626)
# DEBUG - Number of ground truth interactions: 6441
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=888116710) created for algorithm RecentPopularity(K=100)_6472b555-35ba-5b5a-beb6-5161507aba5f
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (6441, 1626)
# DEBUG - Number of ground truth interactions: 6441
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=888116710) created for algorithm RecentPopularity(K=100)_6472b555-35ba-5b5a-beb6-5161507aba5f
# Evaluating steps:  86%|████████▌ | 6/7 [00:01<00:00,  4.19it/s]
# INFO - Phase 3: Releasing the data...
# DEBUG - (user x item) shape defined is (782, 1626). Shape of dataframe stored in matrix was (8919, 5) before masking
# DEBUG - Shape of dataframe stored in matrix is now (8919, 5) after masking
# DEBUG - Final (user x item) shape defined is (782, 1626)
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.101s
# DEBUG - Fitting MostPopular complete - Took 0.00134s
# DEBUG - Fitting RecentPopularity complete - Took 0.000796s
# INFO - Running step 6
# INFO - Phase 2: Evaluating the algorithms...
# DEBUG - (user x item) shape defined is (943, 1626). Shape of dataframe stored in matrix was (11418, 5) before masking
# DEBUG - Shape of dataframe stored in matrix is now (11418, 5) after masking
# DEBUG - Final (user x item) shape defined is (943, 1626)
# DEBUG - (user x item) shape defined is (943, 1626). Shape of dataframe stored in matrix was (11418, 5) before masking
# DEBUG - Shape of dataframe stored in matrix is now (11418, 5) after masking
# DEBUG - Final (user x item) shape defined is (943, 1682)
# DEBUG - Performing items_in comparison
# DEBUG - Padding user ID in range(782, 943) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Shape of prediction matrix: (11418, 1626)
# DEBUG - Shape of ground truth matrix: (11418, 1682)
# WARNING - Prediction matrix shape (11418, 1626) is different from ground truth matrix shape (11418, 1682).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (11418, 1682)
# DEBUG - Number of ground truth interactions: 11418
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=890708710) created for algorithm ItemKNNIncremental(K=100,pad_with_popularity=False)_b82ad9b0-f27f-5ba9-954d-9324325a70d0
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (11418, 1682)
# DEBUG - Number of ground truth interactions: 11418
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=890708710) created for algorithm ItemKNNIncremental(K=100,pad_with_popularity=False)_b82ad9b0-f27f-5ba9-954d-9324325a70d0
# DEBUG - Performing items_in comparison
# DEBUG - Shape of prediction matrix: (11418, 1626)
# DEBUG - Shape of ground truth matrix: (11418, 1682)
# WARNING - Prediction matrix shape (11418, 1626) is different from ground truth matrix shape (11418, 1682).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (11418, 1682)
# DEBUG - Number of ground truth interactions: 11418
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=890708710) created for algorithm MostPopular(K=100)_aa5654e1-ae99-5359-a24b-743deef3f554
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (11418, 1682)
# DEBUG - Number of ground truth interactions: 11418
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=890708710) created for algorithm MostPopular(K=100)_aa5654e1-ae99-5359-a24b-743deef3f554
# DEBUG - Performing items_in comparison
# DEBUG - Shape of prediction matrix: (11418, 1626)
# DEBUG - Shape of ground truth matrix: (11418, 1682)
# WARNING - Prediction matrix shape (11418, 1626) is different from ground truth matrix shape (11418, 1682).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (11418, 1682)
# DEBUG - Number of ground truth interactions: 11418
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=890708710) created for algorithm RecentPopularity(K=100)_6472b555-35ba-5b5a-beb6-5161507aba5f
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (11418, 1682)
# DEBUG - Number of ground truth interactions: 11418
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=890708710) created for algorithm RecentPopularity(K=100)_6472b555-35ba-5b5a-beb6-5161507aba5f
# Evaluating steps: 100%|██████████| 7/7 [00:01<00:00,  4.03it/s]

# %% [markdown]
# # evaluate metrics

# %%
evaluator.metric_results("macro")
# Out:
#                                                                    macro_score  \
# algorithm                                          metric
# ItemKNNIncremental(K=100,pad_with_popularity=Fa... PrecisionK_100     0.001572
#                                                    RecallK_100        0.157206
# MostPopular(K=100)_aa5654e1-ae99-5359-a24b-743d... PrecisionK_100     0.003404
#                                                    RecallK_100        0.340382
# RecentPopularity(K=100)_6472b555-35ba-5b5a-beb6... PrecisionK_100     0.003525
#                                                    RecallK_100        0.352499
#
#                                                                    num_window
# algorithm                                          metric
# ItemKNNIncremental(K=100,pad_with_popularity=Fa... PrecisionK_100           7
#                                                    RecallK_100              7
# MostPopular(K=100)_aa5654e1-ae99-5359-a24b-743d... PrecisionK_100           7
#                                                    RecallK_100              7
# RecentPopularity(K=100)_6472b555-35ba-5b5a-beb6... PrecisionK_100           7
#                                                    RecallK_100              7

# %%
evaluator.metric_results("micro")
# Out:
#                                                                   micro_score  \
# algorithm                                          metric
# ItemKNNIncremental(K=100,pad_with_popularity=Fa... PrecisionK_100    0.003089
#                                                    RecallK_100       0.308891
# MostPopular(K=100)_aa5654e1-ae99-5359-a24b-743d... PrecisionK_100    0.003127
#                                                    RecallK_100       0.312743
# RecentPopularity(K=100)_6472b555-35ba-5b5a-beb6... PrecisionK_100    0.003497
#                                                    RecallK_100       0.349673
#
#                                                                    num_user
# algorithm                                          metric
# ItemKNNIncremental(K=100,pad_with_popularity=Fa... PrecisionK_100      1428
#                                                    RecallK_100         1428
# MostPopular(K=100)_aa5654e1-ae99-5359-a24b-743d... PrecisionK_100      1428
#                                                    RecallK_100         1428
# RecentPopularity(K=100)_6472b555-35ba-5b5a-beb6... PrecisionK_100      1428
#                                                    RecallK_100         1428

# %%
evaluator.metric_results("user")
# Out:
#                                                                               user_id  \
# algorithm                                          timestamp   metric
# ItemKNNIncremental(K=100,pad_with_popularity=Fa... t=875156710 PrecisionK_100       0
#                                                                PrecisionK_100       1
#                                                                PrecisionK_100       2
#                                                                PrecisionK_100       3
#                                                                PrecisionK_100       4
# ...                                                                               ...
# RecentPopularity(K=100)_6472b555-35ba-5b5a-beb6... t=890708710 RecallK_100        938
#                                                                RecallK_100        939
#                                                                RecallK_100        940
#                                                                RecallK_100        941
#                                                                RecallK_100        942
#
#                                                                               user_score
# algorithm                                          timestamp   metric
# ItemKNNIncremental(K=100,pad_with_popularity=Fa... t=875156710 PrecisionK_100       0.01
#                                                                PrecisionK_100      0.007
#                                                                PrecisionK_100      0.008
#                                                                PrecisionK_100      0.005
#                                                                PrecisionK_100      0.006
# ...                                                                                  ...
# RecentPopularity(K=100)_6472b555-35ba-5b5a-beb6... t=890708710 RecallK_100      0.346939
#                                                                RecallK_100      0.807692
#                                                                RecallK_100          0.26
#                                                                RecallK_100      0.466667
#                                                                RecallK_100      0.619048
#
# [8568 rows x 2 columns]

# %%
from streamsight.evaluators import MetricLevelEnum

# %%
# you also can use the Enum instead of string for better code completion support
evaluator.metric_results(MetricLevelEnum.WINDOW)
# Out:
#                                                                                window_score  \
# algorithm                                          timestamp   metric
# ItemKNNIncremental(K=100,pad_with_popularity=Fa... t=875156710 PrecisionK_100      0.000928
#                                                                RecallK_100         0.092765
#                                                    t=877748710 PrecisionK_100      0.000867
#                                                                RecallK_100         0.086653
#                                                    t=880340710 PrecisionK_100      0.001750
#                                                                RecallK_100         0.174989
#                                                    t=882932710 PrecisionK_100      0.001584
#                                                                RecallK_100         0.158386
#                                                    t=885524710 PrecisionK_100      0.001795
#                                                                RecallK_100         0.179520
#                                                    t=888116710 PrecisionK_100      0.002978
#                                                                RecallK_100         0.297780
#                                                    t=890708710 PrecisionK_100      0.001104
#                                                                RecallK_100         0.110352
# MostPopular(K=100)_aa5654e1-ae99-5359-a24b-743d... t=875156710 PrecisionK_100      0.003512
#                                                                RecallK_100         0.351213
#                                                    t=877748710 PrecisionK_100      0.003541
#                                                                RecallK_100         0.354060
#                                                    t=880340710 PrecisionK_100      0.003552
#                                                                RecallK_100         0.355240
#                                                    t=882932710 PrecisionK_100      0.003544
#                                                                RecallK_100         0.354444
#                                                    t=885524710 PrecisionK_100      0.003252
#                                                                RecallK_100         0.325238
#                                                    t=888116710 PrecisionK_100      0.003082
#                                                                RecallK_100         0.308182
#                                                    t=890708710 PrecisionK_100      0.003343
#                                                                RecallK_100         0.334297
# RecentPopularity(K=100)_6472b555-35ba-5b5a-beb6... t=875156710 PrecisionK_100      0.003512
#                                                                RecallK_100         0.351213
#                                                    t=877748710 PrecisionK_100      0.003561
#                                                                RecallK_100         0.356055
#                                                    t=880340710 PrecisionK_100      0.003602
#                                                                RecallK_100         0.360166
#                                                    t=882932710 PrecisionK_100      0.003640
#                                                                RecallK_100         0.364007
#                                                    t=885524710 PrecisionK_100      0.003458
#                                                                RecallK_100         0.345832
#                                                    t=888116710 PrecisionK_100      0.003313
#                                                                RecallK_100         0.331315
#                                                    t=890708710 PrecisionK_100      0.003589
#                                                                RecallK_100         0.358907
#
#                                                                                num_user
# algorithm                                          timestamp   metric
# ItemKNNIncremental(K=100,pad_with_popularity=Fa... t=875156710 PrecisionK_100      8818
#                                                                RecallK_100         8818
#                                                    t=877748710 PrecisionK_100     15037
#                                                                RecallK_100        15037
#                                                    t=880340710 PrecisionK_100      8932
#                                                                RecallK_100         8932
#                                                    t=882932710 PrecisionK_100      8574
#                                                                RecallK_100         8574
#                                                    t=885524710 PrecisionK_100      7041
#                                                                RecallK_100         7041
#                                                    t=888116710 PrecisionK_100      6441
#                                                                RecallK_100         6441
#                                                    t=890708710 PrecisionK_100     11418
#                                                                RecallK_100        11418
# MostPopular(K=100)_aa5654e1-ae99-5359-a24b-743d... t=875156710 PrecisionK_100      8818
#                                                                RecallK_100         8818
#                                                    t=877748710 PrecisionK_100     15037
#                                                                RecallK_100        15037
#                                                    t=880340710 PrecisionK_100      8932
#                                                                RecallK_100         8932
#                                                    t=882932710 PrecisionK_100      8574
#                                                                RecallK_100         8574
#                                                    t=885524710 PrecisionK_100      7041
#                                                                RecallK_100         7041
#                                                    t=888116710 PrecisionK_100      6441
#                                                                RecallK_100         6441
#                                                    t=890708710 PrecisionK_100     11418
#                                                                RecallK_100        11418
# RecentPopularity(K=100)_6472b555-35ba-5b5a-beb6... t=875156710 PrecisionK_100      8818
#                                                                RecallK_100         8818
#                                                    t=877748710 PrecisionK_100     15037
#                                                                RecallK_100        15037
#                                                    t=880340710 PrecisionK_100      8932
#                                                                RecallK_100         8932
#                                                    t=882932710 PrecisionK_100      8574
#                                                                RecallK_100         8574
#                                                    t=885524710 PrecisionK_100      7041
#                                                                RecallK_100         7041
#                                                    t=888116710 PrecisionK_100      6441
#                                                                RecallK_100         6441
#                                                    t=890708710 PrecisionK_100     11418
#                                                                RecallK_100        11418
