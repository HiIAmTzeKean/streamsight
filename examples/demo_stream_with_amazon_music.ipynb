# %% [markdown]
# # Demo of streamsight Stream
#
# - Dataset: AmazonMusicDataset
# - Algorithm: ItemKNN Incremental

# %%
from streamsight.datasets import AmazonMusicDataset
from streamsight.settings import SlidingWindowSetting


k = 100
dataset = AmazonMusicDataset()
data = dataset.load()

setting_window = SlidingWindowSetting(
    background_t=1600052710,
    window_size=60 * 60 * 24 * 30,  # day times N
    top_K=k
)

setting_window.split(data)
# Out:
# INFO - streamsight package loaded.
# DEBUG - AmazonMusicDataset being initialized with '/Users/ngtzekean/personal/streamsight/data/amazon' as the base path.
# DEBUG - AmazonMusicDataset is initialized.
# INFO - AmazonMusicDataset is loading dataset...
# INFO - Loading from cache: /Users/ngtzekean/personal/streamsight/data/amazon/Digital_Music.jsonl.gz.processed.parquet
# DEBUG - AmazonMusicDataset applying filters set.
# DEBUG - 	interactions before preprocess: 130434
# DEBUG - 	items before preprocess: 70511
# DEBUG - 	users before preprocess: 100952
# DEBUG - 	interactions after preprocess: 130434
# DEBUG - 	items after preprocess: 70511
# DEBUG - 	users after preprocess: 100952
# INFO - AmazonMusicDataset dataset loaded - Took 0.104s
# DEBUG - Splitting data...
# DEBUG - Performing lt(t, 2147483647)
# DEBUG - Performing lt(t, 1600052710)
# DEBUG - Performing ge(t, 1600052710)
# DEBUG - TimestampSplitter(t=1600052710,t_lower=None,t_upper=None) has complete split
#   0%|          | 0/36 [00:00<?, ?it/s]
# DEBUG - NLastInteractionTimestampSplitter(t=1600052710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1600052710
# DEBUG - Performing lt(t, 1602644710)
# DEBUG - Performing ge(t, 1600052710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=1600052710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1600052710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1600052710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1602644710
# DEBUG - Performing lt(t, 1605236710)
# DEBUG - Performing ge(t, 1602644710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=1602644710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1602644710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1602644710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1605236710
# DEBUG - Performing lt(t, 1607828710)
# DEBUG - Performing ge(t, 1605236710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=1605236710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1605236710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1605236710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1607828710
# DEBUG - Performing lt(t, 1610420710)
# DEBUG - Performing ge(t, 1607828710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=1607828710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1607828710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1607828710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1610420710
# DEBUG - Performing lt(t, 1613012710)
# DEBUG - Performing ge(t, 1610420710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=1610420710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1610420710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1610420710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1613012710
# DEBUG - Performing lt(t, 1615604710)
# DEBUG - Performing ge(t, 1613012710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=1613012710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1613012710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1613012710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1615604710
# DEBUG - Performing lt(t, 1618196710)
# DEBUG - Performing ge(t, 1615604710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=1615604710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1615604710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1615604710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1618196710
# DEBUG - Performing lt(t, 1620788710)
# DEBUG - Performing ge(t, 1618196710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=1618196710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1618196710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1618196710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1620788710
# DEBUG - Performing lt(t, 1623380710)
# DEBUG - Performing ge(t, 1620788710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=1620788710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1620788710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1620788710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1623380710
# DEBUG - Performing lt(t, 1625972710)
# DEBUG - Performing ge(t, 1623380710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=1623380710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1623380710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1623380710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1625972710
# DEBUG - Performing lt(t, 1628564710)
# DEBUG - Performing ge(t, 1625972710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=1625972710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1625972710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1625972710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1628564710
# DEBUG - Performing lt(t, 1631156710)
# DEBUG - Performing ge(t, 1628564710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=1628564710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1628564710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1628564710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1631156710
# DEBUG - Performing lt(t, 1633748710)
# DEBUG - Performing ge(t, 1631156710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=1631156710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1631156710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1631156710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1633748710
# DEBUG - Performing lt(t, 1636340710)
# DEBUG - Performing ge(t, 1633748710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=1633748710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1633748710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1633748710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1636340710
# DEBUG - Performing lt(t, 1638932710)
# DEBUG - Performing ge(t, 1636340710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=1636340710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1636340710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1636340710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1638932710
# DEBUG - Performing lt(t, 1641524710)
# DEBUG - Performing ge(t, 1638932710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=1638932710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1638932710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1638932710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1641524710
# DEBUG - Performing lt(t, 1644116710)
# DEBUG - Performing ge(t, 1641524710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=1641524710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1641524710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1641524710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1644116710
# DEBUG - Performing lt(t, 1646708710)
# DEBUG - Performing ge(t, 1644116710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=1644116710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1644116710 resulted in empty unlabelled testing samples.
#  50%|█████     | 18/36 [00:00<00:00, 171.27it/s]
# DEBUG - NLastInteractionTimestampSplitter(t=1644116710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1646708710
# DEBUG - Performing lt(t, 1649300710)
# DEBUG - Performing ge(t, 1646708710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=1646708710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1646708710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1646708710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1649300710
# DEBUG - Performing lt(t, 1651892710)
# DEBUG - Performing ge(t, 1649300710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=1649300710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1649300710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1649300710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1651892710
# DEBUG - Performing lt(t, 1654484710)
# DEBUG - Performing ge(t, 1651892710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=1651892710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1651892710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1651892710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1654484710
# DEBUG - Performing lt(t, 1657076710)
# DEBUG - Performing ge(t, 1654484710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=1654484710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1654484710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1654484710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1657076710
# DEBUG - Performing lt(t, 1659668710)
# DEBUG - Performing ge(t, 1657076710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=1657076710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1657076710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1657076710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1659668710
# DEBUG - Performing lt(t, 1662260710)
# DEBUG - Performing ge(t, 1659668710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=1659668710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1659668710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1659668710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1662260710
# DEBUG - Performing lt(t, 1664852710)
# DEBUG - Performing ge(t, 1662260710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=1662260710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1662260710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1662260710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1664852710
# DEBUG - Performing lt(t, 1667444710)
# DEBUG - Performing ge(t, 1664852710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=1664852710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1664852710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1664852710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1667444710
# DEBUG - Performing lt(t, 1670036710)
# DEBUG - Performing ge(t, 1667444710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=1667444710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1667444710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1667444710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1670036710
# DEBUG - Performing lt(t, 1672628710)
# DEBUG - Performing ge(t, 1670036710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=1670036710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1670036710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1670036710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1672628710
# DEBUG - Performing lt(t, 1675220710)
# DEBUG - Performing ge(t, 1672628710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=1672628710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1672628710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1672628710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1675220710
# DEBUG - Performing lt(t, 1677812710)
# DEBUG - Performing ge(t, 1675220710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=1675220710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1675220710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1675220710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1677812710
# DEBUG - Performing lt(t, 1680404710)
# DEBUG - Performing ge(t, 1677812710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=1677812710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1677812710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1677812710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1680404710
# DEBUG - Performing lt(t, 1682996710)
# DEBUG - Performing ge(t, 1680404710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=1680404710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1680404710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1680404710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1682996710
# DEBUG - Performing lt(t, 1685588710)
# DEBUG - Performing ge(t, 1682996710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=1682996710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1682996710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1682996710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1685588710
# DEBUG - Performing lt(t, 1688180710)
# DEBUG - Performing ge(t, 1685588710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=1685588710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1685588710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1685588710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1688180710
# DEBUG - Performing lt(t, 1690772710)
# DEBUG - Performing ge(t, 1688180710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=1688180710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1688180710 resulted in empty unlabelled testing samples.
# DEBUG - NLastInteractionTimestampSplitter(t=1688180710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1690772710
# DEBUG - Performing lt(t, 1693364710)
# DEBUG - Performing ge(t, 1690772710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=1690772710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1690772710 resulted in empty unlabelled testing samples.
# 100%|██████████| 36/36 [00:00<00:00, 169.33it/s]
# DEBUG - NLastInteractionTimestampSplitter(t=1690772710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) - Updating split point to t=1693364710
# DEBUG - Performing lt(t, 1695956710)
# DEBUG - Performing ge(t, 1693364710)
# DEBUG - Performing get_user_n_last_interaction comparison
# DEBUG - NLastInteractionTimestampSplitter(t=1693364710,t_lower=None,t_upper=2592000,n_seq_data=0,include_all_past_data=False) has complete split
# INFO - Split at time 1693364710 resulted in empty unlabelled testing samples.
# 37it [00:00, 169.94it/s]
# INFO - Finished split with window size 2592000 seconds. Number of splits: 37 in total.
# INFO - SlidingWindowSetting data split - Took 0.232s
# DEBUG - Checking split attribute and sizes.
# DEBUG - Checking split attributes.
# DEBUG - Split attributes are set.
# DEBUG - Checking size of split sets.
# DEBUG - Size of split sets are checked.
# INFO - SlidingWindowSetting data split complete.

# %%
from streamsight.evaluators import EvaluatorStreamerBuilder


builder = EvaluatorStreamerBuilder()
builder.add_setting(setting_window)
builder.set_metric_K(k)
builder.add_metric("PrecisionK")
builder.add_metric("RecallK")
builder.add_metric("NDCGK")
evaluator = builder.build()

# %%
from streamsight.algorithms import ItemKNNIncremental


external_model = ItemKNNIncremental(K=k)
external_model_id = evaluator.register_algorithm(algorithm_name="ItemKNNIncremental", algorithm=external_model)
print(external_model_id)
# Out:
# INFO - Registered algorithm 'ItemKNNIncremental' with ID fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020 registered
# fa36fbd0-fe8b-5bd0-921c-35e57e5df020

# %%
evaluator.start_stream()
# Out:
# DEBUG - Restoring setting to iteration 0
# DEBUG - Preparing evaluator for streaming
# DEBUG - (user x item) shape defined is (80587, 59618). Shape of dataframe stored in matrix was (104702, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (104702, 6) after masking
# DEBUG - Final (user x item) shape defined is (80587, 59618)
# DEBUG - Caching evaluation data for step 0
# DEBUG - (user x item) shape defined is (81061, 59618). Shape of dataframe stored in matrix was (604, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (604, 6) after masking
# DEBUG - Final (user x item) shape defined is (81061, 59618)
# DEBUG - (user x item) shape defined is (81061, 59618). Shape of dataframe stored in matrix was (604, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (604, 6) after masking
# DEBUG - Final (user x item) shape defined is (81061, 59919)
# DEBUG - Data cached for step 1 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned NEW -> READY
# DEBUG - Evaluator is ready for streaming
# INFO - Evaluator transitioned to EvaluatorState.STARTED

# %% [markdown]
# # Iteration 1

# %%
data = evaluator.get_training_data(external_model_id)
if data is None:
    raise ValueError("No data available for the external model.")
external_model.fit(data)
# Out:
# DEBUG - Getting data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 34251 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.22s
# ItemKNNIncremental(K=100, pad_with_popularity=False)

# %%
ul_data = evaluator.get_unlabeled_data(external_model_id)
# Out:
# DEBUG - Getting unlabeled data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020

# %%
prediction = external_model.predict(ul_data)
# Out:
# WARNING - ItemKNNIncremental missing similar items for 34251 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding user ID in range(80587, 81061) with random items
# DEBUG - Padding by ItemKNNIncremental completed

# %%
evaluator.submit_prediction(external_model_id, prediction)
# Out:
# DEBUG - Submitting prediction for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - Prediction matrix shape (604, 59618) is different from ground truth matrix shape (604, 59919).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (604, 59919)
# DEBUG - Number of ground truth interactions: 604
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1600052710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (604, 59919)
# DEBUG - Number of ground truth interactions: 604
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1600052710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - NDCGK compute started - NDCGK_100
# DEBUG - Number of users: 604
# DEBUG - Number of ground truth interactions: 604
# DEBUG - NDCGK compute complete - NDCGK_100
# DEBUG - Metric NDCGK_100(timestamp_limit=1600052710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Prediction evaluated for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED

# %% [markdown]
# # Iteration 2

# %%
data = evaluator.get_training_data(external_model_id)
# Out:
# DEBUG - Getting data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - (user x item) shape defined is (81061, 59919). Shape of dataframe stored in matrix was (604, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (604, 6) after masking
# DEBUG - Final (user x item) shape defined is (81061, 59919)
# DEBUG - Caching evaluation data for step 1
# DEBUG - (user x item) shape defined is (81595, 59919). Shape of dataframe stored in matrix was (660, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (660, 6) after masking
# DEBUG - Final (user x item) shape defined is (81595, 59919)
# DEBUG - (user x item) shape defined is (81595, 59919). Shape of dataframe stored in matrix was (660, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (660, 6) after masking
# DEBUG - Final (user x item) shape defined is (81595, 60259)
# DEBUG - Data cached for step 2 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING

# %%
external_model.fit(data)
# Out:
# WARNING - ItemKNNIncremental missing similar items for 34427 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.221s
# ItemKNNIncremental(K=100, pad_with_popularity=False)

# %%
ul_data = evaluator.get_unlabeled_data(external_model_id)
prediction = external_model.predict(ul_data)
evaluator.submit_prediction(external_model_id, prediction)
# Out:
# DEBUG - Getting unlabeled data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - ItemKNNIncremental missing similar items for 34427 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding user ID in range(81061, 81595) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - Prediction matrix shape (660, 59919) is different from ground truth matrix shape (660, 60259).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (660, 60259)
# DEBUG - Number of ground truth interactions: 660
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1602644710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (660, 60259)
# DEBUG - Number of ground truth interactions: 660
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1602644710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - NDCGK compute started - NDCGK_100
# DEBUG - Number of users: 660
# DEBUG - Number of ground truth interactions: 660
# DEBUG - NDCGK compute complete - NDCGK_100
# DEBUG - Metric NDCGK_100(timestamp_limit=1602644710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Prediction evaluated for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED

# %% [markdown]
# # Run till completion

# %%
for i in range(setting_window.num_split - 2):
    data = evaluator.get_training_data(external_model_id)
    external_model.fit(data)
    ul_data = evaluator.get_unlabeled_data(external_model_id)
    prediction = external_model.predict(ul_data)
    evaluator.submit_prediction(external_model_id, prediction)
# Out:
# DEBUG - Getting data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - (user x item) shape defined is (81595, 60259). Shape of dataframe stored in matrix was (660, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (660, 6) after masking
# DEBUG - Final (user x item) shape defined is (81595, 60259)
# DEBUG - Caching evaluation data for step 2
# DEBUG - (user x item) shape defined is (82140, 60259). Shape of dataframe stored in matrix was (678, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (678, 6) after masking
# DEBUG - Final (user x item) shape defined is (82140, 60259)
# DEBUG - (user x item) shape defined is (82140, 60259). Shape of dataframe stored in matrix was (678, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (678, 6) after masking
# DEBUG - Final (user x item) shape defined is (82140, 60597)
# DEBUG - Data cached for step 3 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 34636 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.224s
# DEBUG - Getting unlabeled data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - ItemKNNIncremental missing similar items for 34636 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding user ID in range(81595, 82140) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - Prediction matrix shape (678, 60259) is different from ground truth matrix shape (678, 60597).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (678, 60597)
# DEBUG - Number of ground truth interactions: 678
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1605236710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (678, 60597)
# DEBUG - Number of ground truth interactions: 678
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1605236710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - NDCGK compute started - NDCGK_100
# DEBUG - Number of users: 678
# DEBUG - Number of ground truth interactions: 678
# DEBUG - NDCGK compute complete - NDCGK_100
# DEBUG - Metric NDCGK_100(timestamp_limit=1605236710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Prediction evaluated for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - (user x item) shape defined is (82140, 60597). Shape of dataframe stored in matrix was (678, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (678, 6) after masking
# DEBUG - Final (user x item) shape defined is (82140, 60597)
# DEBUG - Caching evaluation data for step 3
# DEBUG - (user x item) shape defined is (82827, 60597). Shape of dataframe stored in matrix was (835, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (835, 6) after masking
# DEBUG - Final (user x item) shape defined is (82827, 60597)
# DEBUG - (user x item) shape defined is (82827, 60597). Shape of dataframe stored in matrix was (835, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (835, 6) after masking
# DEBUG - Final (user x item) shape defined is (82827, 61011)
# DEBUG - Data cached for step 4 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 34843 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.226s
# DEBUG - Getting unlabeled data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - ItemKNNIncremental missing similar items for 34843 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding user ID in range(82140, 82827) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - Prediction matrix shape (835, 60597) is different from ground truth matrix shape (835, 61011).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (835, 61011)
# DEBUG - Number of ground truth interactions: 835
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1607828710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (835, 61011)
# DEBUG - Number of ground truth interactions: 835
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1607828710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - NDCGK compute started - NDCGK_100
# DEBUG - Number of users: 835
# DEBUG - Number of ground truth interactions: 835
# DEBUG - NDCGK compute complete - NDCGK_100
# DEBUG - Metric NDCGK_100(timestamp_limit=1607828710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Prediction evaluated for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - (user x item) shape defined is (82827, 61011). Shape of dataframe stored in matrix was (835, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (835, 6) after masking
# DEBUG - Final (user x item) shape defined is (82827, 61011)
# DEBUG - Caching evaluation data for step 4
# DEBUG - (user x item) shape defined is (83568, 61011). Shape of dataframe stored in matrix was (907, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (907, 6) after masking
# DEBUG - Final (user x item) shape defined is (83568, 61011)
# DEBUG - (user x item) shape defined is (83568, 61011). Shape of dataframe stored in matrix was (907, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (907, 6) after masking
# DEBUG - Final (user x item) shape defined is (83568, 61462)
# DEBUG - Data cached for step 5 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 35111 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.223s
# DEBUG - Getting unlabeled data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - ItemKNNIncremental missing similar items for 35111 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding user ID in range(82827, 83568) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - Prediction matrix shape (907, 61011) is different from ground truth matrix shape (907, 61462).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (907, 61462)
# DEBUG - Number of ground truth interactions: 907
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1610420710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (907, 61462)
# DEBUG - Number of ground truth interactions: 907
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1610420710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - NDCGK compute started - NDCGK_100
# DEBUG - Number of users: 907
# DEBUG - Number of ground truth interactions: 907
# DEBUG - NDCGK compute complete - NDCGK_100
# DEBUG - Metric NDCGK_100(timestamp_limit=1610420710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Prediction evaluated for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - (user x item) shape defined is (83568, 61462). Shape of dataframe stored in matrix was (907, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (907, 6) after masking
# DEBUG - Final (user x item) shape defined is (83568, 61462)
# DEBUG - Caching evaluation data for step 5
# DEBUG - (user x item) shape defined is (84366, 61462). Shape of dataframe stored in matrix was (985, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (985, 6) after masking
# DEBUG - Final (user x item) shape defined is (84366, 61462)
# DEBUG - (user x item) shape defined is (84366, 61462). Shape of dataframe stored in matrix was (985, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (985, 6) after masking
# DEBUG - Final (user x item) shape defined is (84366, 61930)
# DEBUG - Data cached for step 6 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 35396 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.228s
# DEBUG - Getting unlabeled data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - ItemKNNIncremental missing similar items for 35396 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding user ID in range(83568, 84366) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - Prediction matrix shape (985, 61462) is different from ground truth matrix shape (985, 61930).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (985, 61930)
# DEBUG - Number of ground truth interactions: 985
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1613012710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (985, 61930)
# DEBUG - Number of ground truth interactions: 985
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1613012710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - NDCGK compute started - NDCGK_100
# DEBUG - Number of users: 985
# DEBUG - Number of ground truth interactions: 985
# DEBUG - NDCGK compute complete - NDCGK_100
# DEBUG - Metric NDCGK_100(timestamp_limit=1613012710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Prediction evaluated for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - (user x item) shape defined is (84366, 61930). Shape of dataframe stored in matrix was (985, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (985, 6) after masking
# DEBUG - Final (user x item) shape defined is (84366, 61930)
# DEBUG - Caching evaluation data for step 6
# DEBUG - (user x item) shape defined is (85133, 61930). Shape of dataframe stored in matrix was (1008, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (1008, 6) after masking
# DEBUG - Final (user x item) shape defined is (85133, 61930)
# DEBUG - (user x item) shape defined is (85133, 61930). Shape of dataframe stored in matrix was (1008, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (1008, 6) after masking
# DEBUG - Final (user x item) shape defined is (85133, 62410)
# DEBUG - Data cached for step 7 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 35689 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.224s
# DEBUG - Getting unlabeled data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - ItemKNNIncremental missing similar items for 35689 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding user ID in range(84366, 85133) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - Prediction matrix shape (1008, 61930) is different from ground truth matrix shape (1008, 62410).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (1008, 62410)
# DEBUG - Number of ground truth interactions: 1008
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1615604710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (1008, 62410)
# DEBUG - Number of ground truth interactions: 1008
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1615604710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - NDCGK compute started - NDCGK_100
# DEBUG - Number of users: 1008
# DEBUG - Number of ground truth interactions: 1008
# DEBUG - NDCGK compute complete - NDCGK_100
# DEBUG - Metric NDCGK_100(timestamp_limit=1615604710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Prediction evaluated for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - (user x item) shape defined is (85133, 62410). Shape of dataframe stored in matrix was (1008, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (1008, 6) after masking
# DEBUG - Final (user x item) shape defined is (85133, 62410)
# DEBUG - Caching evaluation data for step 7
# DEBUG - (user x item) shape defined is (85956, 62410). Shape of dataframe stored in matrix was (1046, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (1046, 6) after masking
# DEBUG - Final (user x item) shape defined is (85956, 62410)
# DEBUG - (user x item) shape defined is (85956, 62410). Shape of dataframe stored in matrix was (1046, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (1046, 6) after masking
# DEBUG - Final (user x item) shape defined is (85956, 62909)
# DEBUG - Data cached for step 8 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 35944 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.229s
# DEBUG - Getting unlabeled data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - ItemKNNIncremental missing similar items for 35944 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding user ID in range(85133, 85956) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - Prediction matrix shape (1046, 62410) is different from ground truth matrix shape (1046, 62909).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (1046, 62909)
# DEBUG - Number of ground truth interactions: 1046
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1618196710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (1046, 62909)
# DEBUG - Number of ground truth interactions: 1046
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1618196710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - NDCGK compute started - NDCGK_100
# DEBUG - Number of users: 1046
# DEBUG - Number of ground truth interactions: 1046
# DEBUG - NDCGK compute complete - NDCGK_100
# DEBUG - Metric NDCGK_100(timestamp_limit=1618196710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Prediction evaluated for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - (user x item) shape defined is (85956, 62909). Shape of dataframe stored in matrix was (1046, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (1046, 6) after masking
# DEBUG - Final (user x item) shape defined is (85956, 62909)
# DEBUG - Caching evaluation data for step 8
# DEBUG - (user x item) shape defined is (86639, 62909). Shape of dataframe stored in matrix was (896, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (896, 6) after masking
# DEBUG - Final (user x item) shape defined is (86639, 62909)
# DEBUG - (user x item) shape defined is (86639, 62909). Shape of dataframe stored in matrix was (896, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (896, 6) after masking
# DEBUG - Final (user x item) shape defined is (86639, 63338)
# DEBUG - Data cached for step 9 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 36234 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.231s
# DEBUG - Getting unlabeled data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - ItemKNNIncremental missing similar items for 36234 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding user ID in range(85956, 86639) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - Prediction matrix shape (896, 62909) is different from ground truth matrix shape (896, 63338).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (896, 63338)
# DEBUG - Number of ground truth interactions: 896
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1620788710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (896, 63338)
# DEBUG - Number of ground truth interactions: 896
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1620788710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - NDCGK compute started - NDCGK_100
# DEBUG - Number of users: 896
# DEBUG - Number of ground truth interactions: 896
# DEBUG - NDCGK compute complete - NDCGK_100
# DEBUG - Metric NDCGK_100(timestamp_limit=1620788710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Prediction evaluated for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - (user x item) shape defined is (86639, 63338). Shape of dataframe stored in matrix was (896, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (896, 6) after masking
# DEBUG - Final (user x item) shape defined is (86639, 63338)
# DEBUG - Caching evaluation data for step 9
# DEBUG - (user x item) shape defined is (87393, 63338). Shape of dataframe stored in matrix was (986, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (986, 6) after masking
# DEBUG - Final (user x item) shape defined is (87393, 63338)
# DEBUG - (user x item) shape defined is (87393, 63338). Shape of dataframe stored in matrix was (986, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (986, 6) after masking
# DEBUG - Final (user x item) shape defined is (87393, 63790)
# DEBUG - Data cached for step 10 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 36465 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.231s
# DEBUG - Getting unlabeled data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - ItemKNNIncremental missing similar items for 36465 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding user ID in range(86639, 87393) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - Prediction matrix shape (986, 63338) is different from ground truth matrix shape (986, 63790).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (986, 63790)
# DEBUG - Number of ground truth interactions: 986
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1623380710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (986, 63790)
# DEBUG - Number of ground truth interactions: 986
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1623380710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - NDCGK compute started - NDCGK_100
# DEBUG - Number of users: 986
# DEBUG - Number of ground truth interactions: 986
# DEBUG - NDCGK compute complete - NDCGK_100
# DEBUG - Metric NDCGK_100(timestamp_limit=1623380710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Prediction evaluated for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - (user x item) shape defined is (87393, 63790). Shape of dataframe stored in matrix was (986, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (986, 6) after masking
# DEBUG - Final (user x item) shape defined is (87393, 63790)
# DEBUG - Caching evaluation data for step 10
# DEBUG - (user x item) shape defined is (88137, 63790). Shape of dataframe stored in matrix was (931, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (931, 6) after masking
# DEBUG - Final (user x item) shape defined is (88137, 63790)
# DEBUG - (user x item) shape defined is (88137, 63790). Shape of dataframe stored in matrix was (931, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (931, 6) after masking
# DEBUG - Final (user x item) shape defined is (88137, 64226)
# DEBUG - Data cached for step 11 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 36681 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.236s
# DEBUG - Getting unlabeled data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - ItemKNNIncremental missing similar items for 36681 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding user ID in range(87393, 88137) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - Prediction matrix shape (931, 63790) is different from ground truth matrix shape (931, 64226).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (931, 64226)
# DEBUG - Number of ground truth interactions: 931
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1625972710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (931, 64226)
# DEBUG - Number of ground truth interactions: 931
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1625972710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - NDCGK compute started - NDCGK_100
# DEBUG - Number of users: 931
# DEBUG - Number of ground truth interactions: 931
# DEBUG - NDCGK compute complete - NDCGK_100
# DEBUG - Metric NDCGK_100(timestamp_limit=1625972710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Prediction evaluated for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - (user x item) shape defined is (88137, 64226). Shape of dataframe stored in matrix was (931, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (931, 6) after masking
# DEBUG - Final (user x item) shape defined is (88137, 64226)
# DEBUG - Caching evaluation data for step 11
# DEBUG - (user x item) shape defined is (88756, 64226). Shape of dataframe stored in matrix was (801, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (801, 6) after masking
# DEBUG - Final (user x item) shape defined is (88756, 64226)
# DEBUG - (user x item) shape defined is (88756, 64226). Shape of dataframe stored in matrix was (801, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (801, 6) after masking
# DEBUG - Final (user x item) shape defined is (88756, 64597)
# DEBUG - Data cached for step 12 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 36937 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.239s
# DEBUG - Getting unlabeled data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - ItemKNNIncremental missing similar items for 36937 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding user ID in range(88137, 88756) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - Prediction matrix shape (801, 64226) is different from ground truth matrix shape (801, 64597).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (801, 64597)
# DEBUG - Number of ground truth interactions: 801
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1628564710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (801, 64597)
# DEBUG - Number of ground truth interactions: 801
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1628564710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - NDCGK compute started - NDCGK_100
# DEBUG - Number of users: 801
# DEBUG - Number of ground truth interactions: 801
# DEBUG - NDCGK compute complete - NDCGK_100
# DEBUG - Metric NDCGK_100(timestamp_limit=1628564710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Prediction evaluated for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - (user x item) shape defined is (88756, 64597). Shape of dataframe stored in matrix was (801, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (801, 6) after masking
# DEBUG - Final (user x item) shape defined is (88756, 64597)
# DEBUG - Caching evaluation data for step 12
# DEBUG - (user x item) shape defined is (89339, 64597). Shape of dataframe stored in matrix was (727, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (727, 6) after masking
# DEBUG - Final (user x item) shape defined is (89339, 64597)
# DEBUG - (user x item) shape defined is (89339, 64597). Shape of dataframe stored in matrix was (727, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (727, 6) after masking
# DEBUG - Final (user x item) shape defined is (89339, 64915)
# DEBUG - Data cached for step 13 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 37144 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.238s
# DEBUG - Getting unlabeled data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - ItemKNNIncremental missing similar items for 37144 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding user ID in range(88756, 89339) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - Prediction matrix shape (727, 64597) is different from ground truth matrix shape (727, 64915).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (727, 64915)
# DEBUG - Number of ground truth interactions: 727
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1631156710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (727, 64915)
# DEBUG - Number of ground truth interactions: 727
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1631156710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - NDCGK compute started - NDCGK_100
# DEBUG - Number of users: 727
# DEBUG - Number of ground truth interactions: 727
# DEBUG - NDCGK compute complete - NDCGK_100
# DEBUG - Metric NDCGK_100(timestamp_limit=1631156710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Prediction evaluated for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - (user x item) shape defined is (89339, 64915). Shape of dataframe stored in matrix was (727, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (727, 6) after masking
# DEBUG - Final (user x item) shape defined is (89339, 64915)
# DEBUG - Caching evaluation data for step 13
# DEBUG - (user x item) shape defined is (89903, 64915). Shape of dataframe stored in matrix was (710, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (710, 6) after masking
# DEBUG - Final (user x item) shape defined is (89903, 64915)
# DEBUG - (user x item) shape defined is (89903, 64915). Shape of dataframe stored in matrix was (710, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (710, 6) after masking
# DEBUG - Final (user x item) shape defined is (89903, 65250)
# DEBUG - Data cached for step 14 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 37321 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.241s
# DEBUG - Getting unlabeled data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - ItemKNNIncremental missing similar items for 37321 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding user ID in range(89339, 89903) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - Prediction matrix shape (710, 64915) is different from ground truth matrix shape (710, 65250).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (710, 65250)
# DEBUG - Number of ground truth interactions: 710
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1633748710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (710, 65250)
# DEBUG - Number of ground truth interactions: 710
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1633748710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - NDCGK compute started - NDCGK_100
# DEBUG - Number of users: 710
# DEBUG - Number of ground truth interactions: 710
# DEBUG - NDCGK compute complete - NDCGK_100
# DEBUG - Metric NDCGK_100(timestamp_limit=1633748710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Prediction evaluated for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - (user x item) shape defined is (89903, 65250). Shape of dataframe stored in matrix was (710, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (710, 6) after masking
# DEBUG - Final (user x item) shape defined is (89903, 65250)
# DEBUG - Caching evaluation data for step 14
# DEBUG - (user x item) shape defined is (90419, 65250). Shape of dataframe stored in matrix was (641, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (641, 6) after masking
# DEBUG - Final (user x item) shape defined is (90419, 65250)
# DEBUG - (user x item) shape defined is (90419, 65250). Shape of dataframe stored in matrix was (641, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (641, 6) after masking
# DEBUG - Final (user x item) shape defined is (90419, 65570)
# DEBUG - Data cached for step 15 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 37516 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.247s
# DEBUG - Getting unlabeled data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - ItemKNNIncremental missing similar items for 37516 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding user ID in range(89903, 90419) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - Prediction matrix shape (641, 65250) is different from ground truth matrix shape (641, 65570).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (641, 65570)
# DEBUG - Number of ground truth interactions: 641
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1636340710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (641, 65570)
# DEBUG - Number of ground truth interactions: 641
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1636340710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - NDCGK compute started - NDCGK_100
# DEBUG - Number of users: 641
# DEBUG - Number of ground truth interactions: 641
# DEBUG - NDCGK compute complete - NDCGK_100
# DEBUG - Metric NDCGK_100(timestamp_limit=1636340710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Prediction evaluated for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - (user x item) shape defined is (90419, 65570). Shape of dataframe stored in matrix was (641, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (641, 6) after masking
# DEBUG - Final (user x item) shape defined is (90419, 65570)
# DEBUG - Caching evaluation data for step 15
# DEBUG - (user x item) shape defined is (91169, 65570). Shape of dataframe stored in matrix was (900, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (900, 6) after masking
# DEBUG - Final (user x item) shape defined is (91169, 65570)
# DEBUG - (user x item) shape defined is (91169, 65570). Shape of dataframe stored in matrix was (900, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (900, 6) after masking
# DEBUG - Final (user x item) shape defined is (91169, 65942)
# DEBUG - Data cached for step 16 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 37705 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.242s
# DEBUG - Getting unlabeled data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - ItemKNNIncremental missing similar items for 37705 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding user ID in range(90419, 91169) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - Prediction matrix shape (900, 65570) is different from ground truth matrix shape (900, 65942).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (900, 65942)
# DEBUG - Number of ground truth interactions: 900
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1638932710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (900, 65942)
# DEBUG - Number of ground truth interactions: 900
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1638932710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - NDCGK compute started - NDCGK_100
# DEBUG - Number of users: 900
# DEBUG - Number of ground truth interactions: 900
# DEBUG - NDCGK compute complete - NDCGK_100
# DEBUG - Metric NDCGK_100(timestamp_limit=1638932710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Prediction evaluated for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - (user x item) shape defined is (91169, 65942). Shape of dataframe stored in matrix was (900, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (900, 6) after masking
# DEBUG - Final (user x item) shape defined is (91169, 65942)
# DEBUG - Caching evaluation data for step 16
# DEBUG - (user x item) shape defined is (91916, 65942). Shape of dataframe stored in matrix was (919, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (919, 6) after masking
# DEBUG - Final (user x item) shape defined is (91916, 65942)
# DEBUG - (user x item) shape defined is (91916, 65942). Shape of dataframe stored in matrix was (919, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (919, 6) after masking
# DEBUG - Final (user x item) shape defined is (91916, 66308)
# DEBUG - Data cached for step 17 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 37930 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.245s
# DEBUG - Getting unlabeled data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - ItemKNNIncremental missing similar items for 37930 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding user ID in range(91169, 91916) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - Prediction matrix shape (919, 65942) is different from ground truth matrix shape (919, 66308).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (919, 66308)
# DEBUG - Number of ground truth interactions: 919
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1641524710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (919, 66308)
# DEBUG - Number of ground truth interactions: 919
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1641524710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - NDCGK compute started - NDCGK_100
# DEBUG - Number of users: 919
# DEBUG - Number of ground truth interactions: 919
# DEBUG - NDCGK compute complete - NDCGK_100
# DEBUG - Metric NDCGK_100(timestamp_limit=1641524710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Prediction evaluated for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - (user x item) shape defined is (91916, 66308). Shape of dataframe stored in matrix was (919, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (919, 6) after masking
# DEBUG - Final (user x item) shape defined is (91916, 66308)
# DEBUG - Caching evaluation data for step 17
# DEBUG - (user x item) shape defined is (92479, 66308). Shape of dataframe stored in matrix was (729, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (729, 6) after masking
# DEBUG - Final (user x item) shape defined is (92479, 66308)
# DEBUG - (user x item) shape defined is (92479, 66308). Shape of dataframe stored in matrix was (729, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (729, 6) after masking
# DEBUG - Final (user x item) shape defined is (92479, 66596)
# DEBUG - Data cached for step 18 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 38118 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.244s
# DEBUG - Getting unlabeled data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - ItemKNNIncremental missing similar items for 38118 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding user ID in range(91916, 92479) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - Prediction matrix shape (729, 66308) is different from ground truth matrix shape (729, 66596).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (729, 66596)
# DEBUG - Number of ground truth interactions: 729
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1644116710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (729, 66596)
# DEBUG - Number of ground truth interactions: 729
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1644116710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - NDCGK compute started - NDCGK_100
# DEBUG - Number of users: 729
# DEBUG - Number of ground truth interactions: 729
# DEBUG - NDCGK compute complete - NDCGK_100
# DEBUG - Metric NDCGK_100(timestamp_limit=1644116710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Prediction evaluated for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - (user x item) shape defined is (92479, 66596). Shape of dataframe stored in matrix was (729, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (729, 6) after masking
# DEBUG - Final (user x item) shape defined is (92479, 66596)
# DEBUG - Caching evaluation data for step 18
# DEBUG - (user x item) shape defined is (93083, 66596). Shape of dataframe stored in matrix was (760, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (760, 6) after masking
# DEBUG - Final (user x item) shape defined is (93083, 66596)
# DEBUG - (user x item) shape defined is (93083, 66596). Shape of dataframe stored in matrix was (760, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (760, 6) after masking
# DEBUG - Final (user x item) shape defined is (93083, 66912)
# DEBUG - Data cached for step 19 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 38247 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.251s
# DEBUG - Getting unlabeled data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - ItemKNNIncremental missing similar items for 38247 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding user ID in range(92479, 93083) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - Prediction matrix shape (760, 66596) is different from ground truth matrix shape (760, 66912).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (760, 66912)
# DEBUG - Number of ground truth interactions: 760
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1646708710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (760, 66912)
# DEBUG - Number of ground truth interactions: 760
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1646708710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - NDCGK compute started - NDCGK_100
# DEBUG - Number of users: 760
# DEBUG - Number of ground truth interactions: 760
# DEBUG - NDCGK compute complete - NDCGK_100
# DEBUG - Metric NDCGK_100(timestamp_limit=1646708710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Prediction evaluated for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - (user x item) shape defined is (93083, 66912). Shape of dataframe stored in matrix was (760, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (760, 6) after masking
# DEBUG - Final (user x item) shape defined is (93083, 66912)
# DEBUG - Caching evaluation data for step 19
# DEBUG - (user x item) shape defined is (93574, 66912). Shape of dataframe stored in matrix was (631, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (631, 6) after masking
# DEBUG - Final (user x item) shape defined is (93574, 66912)
# DEBUG - (user x item) shape defined is (93574, 66912). Shape of dataframe stored in matrix was (631, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (631, 6) after masking
# DEBUG - Final (user x item) shape defined is (93574, 67170)
# DEBUG - Data cached for step 20 complete
# ...
# DEBUG - Shape of dataframe stored in matrix is now (444, 6) after masking
# DEBUG - Final (user x item) shape defined is (100357, 70270)
# DEBUG - Data cached for step 32 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 39830 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.263s
# DEBUG - Getting unlabeled data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - ItemKNNIncremental missing similar items for 39830 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding user ID in range(99996, 100357) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - Prediction matrix shape (444, 70109) is different from ground truth matrix shape (444, 70270).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (444, 70270)
# DEBUG - Number of ground truth interactions: 444
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1680404710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (444, 70270)
# DEBUG - Number of ground truth interactions: 444
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1680404710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - NDCGK compute started - NDCGK_100
# DEBUG - Number of users: 444
# DEBUG - Number of ground truth interactions: 444
# DEBUG - NDCGK compute complete - NDCGK_100
# DEBUG - Metric NDCGK_100(timestamp_limit=1680404710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Prediction evaluated for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - (user x item) shape defined is (100357, 70270). Shape of dataframe stored in matrix was (444, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (444, 6) after masking
# DEBUG - Final (user x item) shape defined is (100357, 70270)
# DEBUG - Caching evaluation data for step 32
# DEBUG - (user x item) shape defined is (100578, 70270). Shape of dataframe stored in matrix was (264, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (264, 6) after masking
# DEBUG - Final (user x item) shape defined is (100578, 70270)
# DEBUG - (user x item) shape defined is (100578, 70270). Shape of dataframe stored in matrix was (264, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (264, 6) after masking
# DEBUG - Final (user x item) shape defined is (100578, 70361)
# DEBUG - Data cached for step 33 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 39922 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.257s
# DEBUG - Getting unlabeled data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - ItemKNNIncremental missing similar items for 39922 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding user ID in range(100357, 100578) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - Prediction matrix shape (264, 70270) is different from ground truth matrix shape (264, 70361).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (264, 70361)
# DEBUG - Number of ground truth interactions: 264
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1682996710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (264, 70361)
# DEBUG - Number of ground truth interactions: 264
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1682996710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - NDCGK compute started - NDCGK_100
# DEBUG - Number of users: 264
# DEBUG - Number of ground truth interactions: 264
# DEBUG - NDCGK compute complete - NDCGK_100
# DEBUG - Metric NDCGK_100(timestamp_limit=1682996710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Prediction evaluated for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - (user x item) shape defined is (100578, 70361). Shape of dataframe stored in matrix was (264, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (264, 6) after masking
# DEBUG - Final (user x item) shape defined is (100578, 70361)
# DEBUG - Caching evaluation data for step 33
# DEBUG - (user x item) shape defined is (100741, 70361). Shape of dataframe stored in matrix was (183, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (183, 6) after masking
# DEBUG - Final (user x item) shape defined is (100741, 70361)
# DEBUG - (user x item) shape defined is (100741, 70361). Shape of dataframe stored in matrix was (183, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (183, 6) after masking
# DEBUG - Final (user x item) shape defined is (100741, 70422)
# DEBUG - Data cached for step 34 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 39978 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.26s
# DEBUG - Getting unlabeled data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - ItemKNNIncremental missing similar items for 39978 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding user ID in range(100578, 100741) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - Prediction matrix shape (183, 70361) is different from ground truth matrix shape (183, 70422).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (183, 70422)
# DEBUG - Number of ground truth interactions: 183
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1685588710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (183, 70422)
# DEBUG - Number of ground truth interactions: 183
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1685588710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - NDCGK compute started - NDCGK_100
# DEBUG - Number of users: 183
# DEBUG - Number of ground truth interactions: 183
# DEBUG - NDCGK compute complete - NDCGK_100
# DEBUG - Metric NDCGK_100(timestamp_limit=1685588710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Prediction evaluated for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - (user x item) shape defined is (100741, 70422). Shape of dataframe stored in matrix was (183, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (183, 6) after masking
# DEBUG - Final (user x item) shape defined is (100741, 70422)
# DEBUG - Caching evaluation data for step 34
# DEBUG - (user x item) shape defined is (100853, 70422). Shape of dataframe stored in matrix was (128, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (128, 6) after masking
# DEBUG - Final (user x item) shape defined is (100853, 70422)
# DEBUG - (user x item) shape defined is (100853, 70422). Shape of dataframe stored in matrix was (128, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (128, 6) after masking
# DEBUG - Final (user x item) shape defined is (100853, 70472)
# DEBUG - Data cached for step 35 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 40026 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.257s
# DEBUG - Getting unlabeled data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - ItemKNNIncremental missing similar items for 40026 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding user ID in range(100741, 100853) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - Prediction matrix shape (128, 70422) is different from ground truth matrix shape (128, 70472).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (128, 70472)
# DEBUG - Number of ground truth interactions: 128
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1688180710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (128, 70472)
# DEBUG - Number of ground truth interactions: 128
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1688180710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - NDCGK compute started - NDCGK_100
# DEBUG - Number of users: 128
# DEBUG - Number of ground truth interactions: 128
# DEBUG - NDCGK compute complete - NDCGK_100
# DEBUG - Metric NDCGK_100(timestamp_limit=1688180710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Prediction evaluated for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - (user x item) shape defined is (100853, 70472). Shape of dataframe stored in matrix was (128, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (128, 6) after masking
# DEBUG - Final (user x item) shape defined is (100853, 70472)
# DEBUG - Caching evaluation data for step 35
# DEBUG - (user x item) shape defined is (100942, 70472). Shape of dataframe stored in matrix was (108, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (108, 6) after masking
# DEBUG - Final (user x item) shape defined is (100942, 70472)
# DEBUG - (user x item) shape defined is (100942, 70472). Shape of dataframe stored in matrix was (108, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (108, 6) after masking
# DEBUG - Final (user x item) shape defined is (100942, 70508)
# DEBUG - Data cached for step 36 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 40058 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.266s
# DEBUG - Getting unlabeled data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - ItemKNNIncremental missing similar items for 40058 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding user ID in range(100853, 100942) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - Prediction matrix shape (108, 70472) is different from ground truth matrix shape (108, 70508).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (108, 70508)
# DEBUG - Number of ground truth interactions: 108
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1690772710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (108, 70508)
# DEBUG - Number of ground truth interactions: 108
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1690772710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - NDCGK compute started - NDCGK_100
# DEBUG - Number of users: 108
# DEBUG - Number of ground truth interactions: 108
# DEBUG - NDCGK compute complete - NDCGK_100
# DEBUG - Metric NDCGK_100(timestamp_limit=1690772710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Prediction evaluated for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED
# DEBUG - Getting data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - (user x item) shape defined is (100942, 70508). Shape of dataframe stored in matrix was (108, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (108, 6) after masking
# DEBUG - Final (user x item) shape defined is (100942, 70508)
# DEBUG - Caching evaluation data for step 36
# DEBUG - (user x item) shape defined is (100952, 70508). Shape of dataframe stored in matrix was (11, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (11, 6) after masking
# DEBUG - Final (user x item) shape defined is (100952, 70508)
# DEBUG - (user x item) shape defined is (100952, 70508). Shape of dataframe stored in matrix was (11, 6) before masking
# DEBUG - Shape of dataframe stored in matrix is now (11, 6) after masking
# DEBUG - Final (user x item) shape defined is (100952, 70511)
# DEBUG - Data cached for step 37 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned PREDICTED -> READY
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned READY -> RUNNING
# WARNING - ItemKNNIncremental missing similar items for 40077 items.
# DEBUG - Fitting ItemKNNIncremental complete - Took 0.26s
# DEBUG - Getting unlabeled data for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - ItemKNNIncremental missing similar items for 40077 items.
# DEBUG - Performing items_in comparison
# DEBUG - Padding user ID in range(100942, 100952) with random items
# DEBUG - Padding by ItemKNNIncremental completed
# DEBUG - Submitting prediction for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# WARNING - Prediction matrix shape (11, 70508) is different from ground truth matrix shape (11, 70511).
# DEBUG - Precision compute started - PrecisionK_100
# DEBUG - Shape of matrix: (11, 70511)
# DEBUG - Number of ground truth interactions: 11
# DEBUG - Precision compute complete - PrecisionK_100
# DEBUG - Metric PrecisionK_100(timestamp_limit=1693364710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Precision compute started - RecallK_100
# DEBUG - Shape of matrix: (11, 70511)
# DEBUG - Number of ground truth interactions: 11
# DEBUG - Recall compute complete - RecallK_100
# DEBUG - Metric RecallK_100(timestamp_limit=1693364710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - NDCGK compute started - NDCGK_100
# DEBUG - Number of users: 11
# DEBUG - Number of ground truth interactions: 11
# DEBUG - NDCGK compute complete - NDCGK_100
# DEBUG - Metric NDCGK_100(timestamp_limit=1693364710) created for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020
# DEBUG - Prediction evaluated for algorithm fa36fbd0-fe8b-5bd0-921c-35e57e5df020 complete
# DEBUG - Algorithm 'ItemKNNIncremental' transitioned RUNNING -> PREDICTED

# %% [markdown]
# # evaluate metrics

# %%
evaluator.get_all_algorithm_status()
# Out:
# {'ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020': <AlgorithmStateEnum.PREDICTED: 'PREDICTED'>}

# %%
evaluator.metric_results("macro")
# Out:
# WARNING - All predictions were off or the ground truth matrix was empty during compute of PrecisionK_100(timestamp_limit=1610420710).
# INFO - Metric PrecisionK_100 for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 at t=1610420710 has 0 score but there are interactions. ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of RecallK_100(timestamp_limit=1610420710).
# INFO - Metric RecallK_100 for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 at t=1610420710 has 0 score but there are interactions. ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of NDCGK_100(timestamp_limit=1610420710).
# INFO - Metric NDCGK_100 for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 at t=1610420710 has 0 score but there are interactions. ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of PrecisionK_100(timestamp_limit=1623380710).
# INFO - Metric PrecisionK_100 for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 at t=1623380710 has 0 score but there are interactions. ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of RecallK_100(timestamp_limit=1623380710).
# INFO - Metric RecallK_100 for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 at t=1623380710 has 0 score but there are interactions. ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of NDCGK_100(timestamp_limit=1623380710).
# INFO - Metric NDCGK_100 for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 at t=1623380710 has 0 score but there are interactions. ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of PrecisionK_100(timestamp_limit=1677812710).
# INFO - Metric PrecisionK_100 for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 at t=1677812710 has 0 score but there are interactions. ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of RecallK_100(timestamp_limit=1677812710).
# INFO - Metric RecallK_100 for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 at t=1677812710 has 0 score but there are interactions. ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of NDCGK_100(timestamp_limit=1677812710).
# INFO - Metric NDCGK_100 for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 at t=1677812710 has 0 score but there are interactions. ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of PrecisionK_100(timestamp_limit=1688180710).
# INFO - Metric PrecisionK_100 for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 at t=1688180710 has 0 score but there are interactions. ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of RecallK_100(timestamp_limit=1688180710).
# INFO - Metric RecallK_100 for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 at t=1688180710 has 0 score but there are interactions. ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of NDCGK_100(timestamp_limit=1688180710).
# INFO - Metric NDCGK_100 for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 at t=1688180710 has 0 score but there are interactions. ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of PrecisionK_100(timestamp_limit=1690772710).
# INFO - Metric PrecisionK_100 for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 at t=1690772710 has 0 score but there are interactions. ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of RecallK_100(timestamp_limit=1690772710).
# INFO - Metric RecallK_100 for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 at t=1690772710 has 0 score but there are interactions. ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of NDCGK_100(timestamp_limit=1690772710).
# INFO - Metric NDCGK_100 for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 at t=1690772710 has 0 score but there are interactions. ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of PrecisionK_100(timestamp_limit=1693364710).
# INFO - Metric PrecisionK_100 for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 at t=1693364710 has 0 score but there are interactions. ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of RecallK_100(timestamp_limit=1693364710).
# INFO - Metric RecallK_100 for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 at t=1693364710 has 0 score but there are interactions. ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of NDCGK_100(timestamp_limit=1693364710).
# INFO - Metric NDCGK_100 for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 at t=1693364710 has 0 score but there are interactions. ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 did not have any correct predictions.
#                                                                    macro_score  \
# algorithm                                          metric
# ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e5... NDCGK_100          0.022536
#                                                    PrecisionK_100     0.000029
#                                                    RecallK_100        0.002912
#
#                                                                    num_window
# algorithm                                          metric
# ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e5... NDCGK_100               37
#                                                    PrecisionK_100          37
#                                                    RecallK_100             37

# %%
evaluator.metric_results("micro")
# Out:
#                                                                   micro_score  \
# algorithm                                          metric
# ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e5... NDCGK_100         0.014832
#                                                    PrecisionK_100    0.000023
#                                                    RecallK_100       0.002309
#
#                                                                    num_user
# algorithm                                          metric
# ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e5... NDCGK_100          24053
#                                                    PrecisionK_100     24053
#                                                    RecallK_100        24053

# %%
evaluator.metric_results("user")
# Out:
#                                                                                user_id  \
# algorithm                                          timestamp    metric
# ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e5... t=1600052710 PrecisionK_100      76
#                                                                 PrecisionK_100    2104
#                                                                 PrecisionK_100    2395
#                                                                 PrecisionK_100    3359
#                                                                 PrecisionK_100    6472
# ...                                                                                ...
#                                                    t=1693364710 NDCGK_100       100947
#                                                                 NDCGK_100       100948
#                                                                 NDCGK_100       100949
#                                                                 NDCGK_100       100950
#                                                                 NDCGK_100       100951
#
#                                                                                user_score
# algorithm                                          timestamp    metric
# ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e5... t=1600052710 PrecisionK_100        0.0
#                                                                 PrecisionK_100        0.0
#                                                                 PrecisionK_100        0.0
#                                                                 PrecisionK_100        0.0
#                                                                 PrecisionK_100        0.0
# ...                                                                                   ...
#                                                    t=1693364710 NDCGK_100             0.0
#                                                                 NDCGK_100             0.0
#                                                                 NDCGK_100             0.0
#                                                                 NDCGK_100             0.0
#                                                                 NDCGK_100             0.0
#
# [72159 rows x 2 columns]

# %%
evaluator.metric_results("window")
# Out:
# WARNING - All predictions were off or the ground truth matrix was empty during compute of PrecisionK_100(timestamp_limit=1610420710).
# INFO - Metric PrecisionK_100 for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 at t=1610420710 has 0 score but there are interactions. ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of RecallK_100(timestamp_limit=1610420710).
# INFO - Metric RecallK_100 for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 at t=1610420710 has 0 score but there are interactions. ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of NDCGK_100(timestamp_limit=1610420710).
# INFO - Metric NDCGK_100 for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 at t=1610420710 has 0 score but there are interactions. ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of PrecisionK_100(timestamp_limit=1623380710).
# INFO - Metric PrecisionK_100 for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 at t=1623380710 has 0 score but there are interactions. ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of RecallK_100(timestamp_limit=1623380710).
# INFO - Metric RecallK_100 for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 at t=1623380710 has 0 score but there are interactions. ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of NDCGK_100(timestamp_limit=1623380710).
# INFO - Metric NDCGK_100 for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 at t=1623380710 has 0 score but there are interactions. ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of PrecisionK_100(timestamp_limit=1677812710).
# INFO - Metric PrecisionK_100 for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 at t=1677812710 has 0 score but there are interactions. ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of RecallK_100(timestamp_limit=1677812710).
# INFO - Metric RecallK_100 for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 at t=1677812710 has 0 score but there are interactions. ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of NDCGK_100(timestamp_limit=1677812710).
# INFO - Metric NDCGK_100 for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 at t=1677812710 has 0 score but there are interactions. ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of PrecisionK_100(timestamp_limit=1688180710).
# INFO - Metric PrecisionK_100 for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 at t=1688180710 has 0 score but there are interactions. ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of RecallK_100(timestamp_limit=1688180710).
# INFO - Metric RecallK_100 for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 at t=1688180710 has 0 score but there are interactions. ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of NDCGK_100(timestamp_limit=1688180710).
# INFO - Metric NDCGK_100 for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 at t=1688180710 has 0 score but there are interactions. ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of PrecisionK_100(timestamp_limit=1690772710).
# INFO - Metric PrecisionK_100 for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 at t=1690772710 has 0 score but there are interactions. ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of RecallK_100(timestamp_limit=1690772710).
# INFO - Metric RecallK_100 for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 at t=1690772710 has 0 score but there are interactions. ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of NDCGK_100(timestamp_limit=1690772710).
# INFO - Metric NDCGK_100 for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 at t=1690772710 has 0 score but there are interactions. ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of PrecisionK_100(timestamp_limit=1693364710).
# INFO - Metric PrecisionK_100 for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 at t=1693364710 has 0 score but there are interactions. ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of RecallK_100(timestamp_limit=1693364710).
# INFO - Metric RecallK_100 for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 at t=1693364710 has 0 score but there are interactions. ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 did not have any correct predictions.
# WARNING - All predictions were off or the ground truth matrix was empty during compute of NDCGK_100(timestamp_limit=1693364710).
# INFO - Metric NDCGK_100 for algorithm ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 at t=1693364710 has 0 score but there are interactions. ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e57e5df020 did not have any correct predictions.
#                                                                                 window_score  \
# algorithm                                          timestamp    metric
# ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e5... t=1600052710 PrecisionK_100      0.000017
#                                                                 RecallK_100         0.001656
#                                                                 NDCGK_100           0.036661
#                                                    t=1602644710 PrecisionK_100      0.000076
#                                                                 RecallK_100         0.007576
# ...                                                                                      ...
#                                                    t=1690772710 RecallK_100         0.000000
#                                                                 NDCGK_100           0.000000
#                                                    t=1693364710 PrecisionK_100      0.000000
#                                                                 RecallK_100         0.000000
#                                                                 NDCGK_100           0.000000
#
#                                                                                 num_user
# algorithm                                          timestamp    metric
# ItemKNNIncremental_fa36fbd0-fe8b-5bd0-921c-35e5... t=1600052710 PrecisionK_100       604
#                                                                 RecallK_100          604
#                                                                 NDCGK_100            604
#                                                    t=1602644710 PrecisionK_100       660
#                                                                 RecallK_100          660
# ...                                                                                  ...
#                                                    t=1690772710 RecallK_100          108
#                                                                 NDCGK_100            108
#                                                    t=1693364710 PrecisionK_100        11
#                                                                 RecallK_100           11
#                                                                 NDCGK_100             11
#
# [111 rows x 2 columns]
